# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %%
#Import the Necessary Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Import the Necessary Libraries
# ----> 2 import pandas as pd
#       3 from sklearn.model_selection import train_test_split
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/compat/__init__.py:25
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     PY39,
#    (...)
#      22     PYPY,
#      23 )
#      24 import pandas.compat.compressors
# ---> 25 from pandas.compat.numpy import (
#      26     is_numpy_dev,
#      27     np_version_under1p21,
#      28 )
#      29 from pandas.compat.pyarrow import (
#      30     pa_version_under7p0,
#      31     pa_version_under8p0,
#      32     pa_version_under9p0,
#      33     pa_version_under11p0,
#      34 )
#      37 def set_function_name(f: F, name: str, cls) -> F:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/compat/numpy/__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
#Load the data sets- train and test
df=pd.read_csv('train.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #Load the data sets- train and test
# ----> 2 df=pd.read_csv('train.csv')
#       3 df
#
# NameError: name 'pd' is not defined

# %%
#Look at top values of train data 
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Look at top values of train data
# ----> 2 df.head()
#
# NameError: name 'df' is not defined

# %%
#Print the column names of train data
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Print the column names of train data
# ----> 2 df.columns
#
# NameError: name 'df' is not defined

# %%
#Print the dimension of train and test data
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Print the dimension of train and test data
# ----> 2 df.shape
#
# NameError: name 'df' is not defined

# %%
#Print the number of missing values in each column of train and test data
null = df.isnull().sum()
null
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #Print the number of missing values in each column of train and test data
# ----> 2 null = df.isnull().sum()
#       3 null
#
# NameError: name 'df' is not defined

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
#Barchart of Survived, Pclass, Sex, Embarked

columns=['Survived','Pclass','Sex','Embarked']
for column in columns:
    df[column].value_counts().plot(kind='bar',color='green')
    plt.show()

# %%
#Histogram of Age, Parch, Fare

column1 = ['Age', 'Parch', 'Fare']
for column in columns:
    df[column].value_counts().plot(kind='hist', color='green')
    plt.show()

# %%
#Plot histogram of age for survived and did not survived class
import matplotlib.pyplot as plt

# Separate the ages based on survival status
age_survived = df[df['Survived'] == 1]['Age']
age_not_survived = df[df['Survived'] == 0]['Age']

# Plot histograms for the two groups
plt.hist(age_survived, alpha=0.5, label="Survived", bins=20)
plt.hist(age_not_survived, alpha=0.5, label="Not Survived", bins=20)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age vs Survived")
plt.legend()
plt.show()

# %%
#Count class and geder wise survival rate - plot with appropriate chart
#Age wise Distribution of Male and Female passengers
# 1️⃣ Class & Gender-wise Survival Rate
plt.figure(figsize=(10, 5))
sns.barplot(x="Pclass", y="Survived", hue="Sex",
            data=df, ci=None, palette="pastel")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")
plt.title("Class & Gender-wise Survival Rate")
plt.show()

# 2️⃣ Age-wise Distribution of Male & Female Passengers
plt.figure(figsize=(10, 5))
sns.histplot(df[df["Sex"] == "male"]["Age"], bins=30,
             color="blue", label="Male", kde=True, alpha=0.6)
sns.histplot(df[df["Sex"] == "female"]["Age"], bins=30,
             color="pink", label="Female", kde=True, alpha=0.6)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age-wise Distribution of Male & Female Passengers")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_6958/2780586972.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Pclass", y="Survived", hue="Sex",

# %%
#Histogram of Age of the given data set(sample)
plt.figure(figsize=(10, 5))
sns.histplot(df["Age"].dropna(), bins=30, kde=True, color="purple", alpha=0.7)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram of Age Distribution")
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace the msiing values in Embarked column by 'S'

# %%
#Impute the missing values in Fare column with median value

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch + SibSp + 1
df['FamilySize']=df['Parch']+df['SibSp']+1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0        1      0         A/5 21171   7.2500   NaN        S           2
# 1        1      0          PC 17599  71.2833   C85        C           2
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S           1
# 3        1      0            113803  53.1000  C123        S           2
# 4        0      0            373450   8.0500   NaN        S           1
# ..     ...    ...               ...      ...   ...      ...         ...
# 886      0      0            211536  13.0000   NaN        S           1
# 887      0      0            112053  30.0000   B42        S           1
# 888      1      2        W./C. 6607  23.4500   NaN        S           4
# 889      0      0            111369  30.0000  C148        C           1
# 890      0      0            370376   7.7500   NaN        Q           1
#
# [891 rows x 13 columns]

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False
df['IsAlone']=df['FamilySize']==1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  FamilySize  \
# 0        1      0         A/5 21171   7.2500   NaN        S           2
# 1        1      0          PC 17599  71.2833   C85        C           2
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S           1
# 3        1      0            113803  53.1000  C123        S           2
# 4        0      0            373450   8.0500   NaN        S           1
# ..     ...    ...               ...      ...   ...      ...         ...
# 886      0      0            211536  13.0000   NaN        S           1
# 887      0      0            112053  30.0000   B42        S           1
# 888      1      2        W./C. 6607  23.4500   NaN        S           4
# 889      0      0            111369  30.0000  C148        C           1
# 890      0      0            370376   7.7500   NaN        Q           1
#
#      IsAlone
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
# ..       ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
#
# [891 rows x 14 columns]

# %% [markdown]
# ## Create a new attribute Has_cabin using the attribue Cabin.
# #if Cabin == NaN the Has_cabin = False else Has_cabin = True

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId, Name, Ticket, and Cabin
if df['Cabin']==NaN:
    df['Has_cabin']=False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 #Drop the columns which may not be useful in prediction of survival
#       2 #Drop PassengerId, Name, Ticket, and Cabin
# ----> 3 if df['Cabin']==NaN:
#       4     df['Has_cabin']=False
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Model Building

# %%
#Prepare X and y

# %%
# Label encoding of categorical features

# %%
# concat df_categorical with original df

# %%
#Do a pairplot of all features

# %%
X

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library

# %%
#Print the tree

# Importing required packages for visualization

# %%
# plotting tree with max_depth=3

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report

# %%
# Printing confusion matrix and accuracy
